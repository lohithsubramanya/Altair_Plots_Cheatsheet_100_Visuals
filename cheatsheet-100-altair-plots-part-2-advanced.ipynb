# %% [markdown]
# <font size="+3" color=purple><b> <center><u>Cheatsheet - 100+ Altair Plots - Part 2</u></center></b></font>

# %% [markdown]
# # Objective
#
# The aim of this kernel is provide all essential and most commonly used altair charts in a single page.This kernel will hold advanced charts and different attributes used for them.It could be a great time saver for you.Just utilize it anytime when you are working on data visualizations.
#
# <font size="+1"><b><u>Altair:</u></b></font><br>
# Altair is a declarative library for data visualization. Its principle is that rather than focusing on the code part, one should focus on the visualization part and write as less code as possible and still be able to create beautiful and intuitive plots.Since Altair uses a declarative style to create plots, it becomes very easy and quick to iterate through visualizations and experiments at a rapid pace when using this library.This can stand as alternative for matplotlib and other visualization libraries.
#
# I have learned them from [altair community](https://altair-viz.github.io/gallery/index.html) and deployed them on datasets available in kaggle platform.There are two parts of my kernel.
#
# **Part 1** : https://www.kaggle.com/raenish/cheatsheet-100-altair-plots-part-1-basic/<br>
# **Part 2** : <font color="blue" >you are on it</font>
#
#
# In this part ,you will find <font color="blue"><b>heatmaps,maps,violin,error,gantt plots</b></font> and many more amazing <font color="blue" ><b>multiple interactive/reflective plots</b></font> which is more interesting in Altair series

# %% [markdown]
# <font size="+1" color=chocolate ><b>Please Upvote my kernel and keep it in your favourite section if you think it is helpful.</b></font>

# %% [markdown]
# <a id="top"></a>
#
# <div class="list-group" id="list-tab" role="tablist">
# <h3 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Table of content</h3>
#
# * [Starters](#0)
#
# <font color="blueviolet" size=+1><b>Heatmap</b></font>
# * [72. Basic Heatmap](#72)
# * [73. Heatmap Color gradient](#73)
# * [74. Binned Heatmap](#74)
# * [75. Text Over Heatmap](#75)
# * [76. Date Heatmap](#76)
#
# <font color="green" size=+1><b>Error</b></font>
# * [77. Simple Scatter Error Plot](#77)
# * [78. Grouped Bar with Error](#78)
# * [79. Error Bar with Standard Deviation](#79)
# * [80. Error Bar with Confidence Interval](#80)
# * [81. Sorted Error Bar with Confidence Interval](#81)
#
# <font color="orangered" size=+1><b>Candlestick</b></font>
# * [82. Candlestick](#82)
#
# <font color="olive" size=+1><b>Violin</b></font>
# * [83. Basic Violin](#83)
# * [84. Multiple Violin](#84)
#
# <font color="limegreen" size=+1><b>Gantt</b></font>
# * [85. Gantt](#85)
# * [86. Gantt Color & Mean Chart](#86)
#
# <font color="teal" size=+1><b>Ridgeline</b></font>
# * [87. Ridgeline](#87)
#
# <font color="firebrick" size=+1><b>Map</b></font>
# * [88. Choropleth](#88)
# * [89. Location](#89)
# * [90. Repeated Choropleth](#90)
# * [91. Facet](#91)
# * [92. World Map](#92)
# * [93. World Projections](#93)
#
# <font color="deeppink" size=+1><b>Interactive</b></font>
# * [94. Interactive Average](#94)
# * [95. Interactive Chart with Cross-Highlight](#95)
# * [96. Interactive Chart with Crossfilter](#96)
# * [97. Interactive Legend](#97)
# * [98. Interactive Rectangular Brush](#98)
# * [99. Interactive Scatter Plot and Linked Layered Histogram](#99)
# * [100. Multi-Line Highlight](#100)
# * [101. Multi-panel Scatter Plot with Linked Brushing](#101)

# %% [markdown]
# ### Library

# %%
# !pip install vega_datasets

# %%
import numpy as np
import pandas as pd

import altair as alt
from vega_datasets import data

# %% [markdown]
# ### Data

# %%
campus=pd.read_csv('../input/factors-affecting-campus-placement/Placement_Data_Full_Class.csv')
health=pd.read_csv('../input/av-healthcare-analytics-ii/healthcare/train_data.csv')
university=pd.read_csv('../input/world-university-rankings/cwurData.csv')
book_rate=pd.read_csv('../input/bookcrossing-dataset/Book reviews/BX-Book-Ratings.csv', delimiter=';', nrows = 1000)
book_users=pd.read_csv('../input/bookcrossing-dataset/Book reviews/BX-Users.csv', sep=';',  encoding='latin-1',low_memory=False)
delhi_house=pd.read_csv('../input/housing-prices-in-metropolitan-areas-of-india/Delhi.csv')
netflix=pd.read_csv('../input/netflix-shows/netflix_titles.csv')
covid=pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv')
chennai_house=pd.read_csv('../input/housing-prices-in-metropolitan-areas-of-india/Chennai.csv')
stack=pd.read_csv('../input/60k-stack-overflow-questions-with-quality-rate/data.csv')
windows=pd.read_csv('../input/windows-store/msft.csv')
playstore=pd.read_csv('../input/google-play-store-apps/googleplaystore.csv')
cipla=pd.read_csv('../input/nifty50-stock-market-data/CIPLA.csv')
axis=pd.read_csv('../input/nifty50-stock-market-data/AXISBANK.csv')
hdfc=pd.read_csv('../input/nifty50-stock-market-data/HDFCBANK.csv')
icici=pd.read_csv('../input/nifty50-stock-market-data/ICICIBANK.csv')
indus=pd.read_csv('../input/nifty50-stock-market-data/INDUSINDBK.csv')
kotak=pd.read_csv('../input/nifty50-stock-market-data/KOTAKBANK.csv')
infy=pd.read_csv('../input/nifty50-stock-market-data/INFY.csv')
titanic=pd.read_csv('../input/titanic/train.csv')
covid=pd.read_csv('../input/novel-corona-virus-2019-dataset/covid_19_data.csv')
health=pd.read_csv('../input/av-healthcare-analytics-ii/healthcare/train_data.csv')

# %% [markdown]
# <a id="0"></a>
# <font color="black" size=+2.5><b>Starters</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %% [markdown]
# **Properties:**
#
# * `Chart` - takes a dataframe as a single argument. alt.Chart(dataframe)
# * `encode()`- builds a key-value mapping between encoding channels (such as x, y, color, shape, size, etc.)
#
# * `color`- The color of the mark
# * `fill` - The fill for the mark
# * `fillOpacity` - The opacity of the mark’s fill
# * `opacity` - The opacity of the mark
# * `shape` - The shape of the mark
# * `size` - The size of the mark
# * `stroke` - The stroke of the mark
# * `strokeDash` - The stroke dash style
# * `strokeOpacity` - The opacity of the line
# * `strokeWidth` - The width of the line
# * `text` - Text to use for the mark
# * `tooltip` - The tooltip value
# * `href` - Hyperlink for points
# * `order` -	Sets the order of the marks
#
# **Encoding Data Types:**
#
# * **quantitative** - `Q`	- a continuous real-valued quantity
# * **ordinal** -	`O` - a discrete ordered quantity
# * **nominal** -	`N` -	a discrete unordered category
# * **temporal** - `T` -	a time or date value
# * **geojson** -	`G` -	a geographic shape
#
# More attribute details here :https://altair-viz.github.io/user_guide/encoding.html

# %% [markdown]
# <a id="72"></a>
# <font color="blueviolet" size=+2.5><b>72. Basic Heatmap</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
alt.Chart(health.sample(5000)).mark_rect().encode(
    x='Age',
    y='Stay',
    color='Admission_Deposit',
    tooltip=['Age','Stay','Admission_Deposit']
).properties(width=550,height=380,title="Age vs Stay against Initial Deposit")

# %% [markdown]
# <a id="73"></a>
# <font color="blueviolet" size=+2.5><b>73. Heatmap Color Gradient</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
ind_univer=university[university['country']=='India']

# %%
alt.Chart(ind_univer).mark_rect().encode(
    x='institution:O',
    y='year:O',
    color=alt.Color('score:Q',scale=alt.Scale(type='log',scheme='purples')),
    tooltip=['year','institution','score']
).properties(width=600,height=400,title="Score of Indian Institutes")

# Change scheme - https://vega.github.io/vega/docs/schemes/

# %% [markdown]
# <a id="74"></a>
# <font color="blueviolet" size=+2.5><b>74. Binned Heatmap</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
comm_campus=campus[(campus['degree_t']=='Comm&Mgmt')&(campus['status']!="Not Placed")]

# %%
alt.Chart(comm_campus).mark_rect().encode(
    alt.X('degree_p:Q', bin=alt.Bin(maxbins=3)),
    alt.Y('etest_p:Q', bin=alt.Bin(maxbins=5)),
    alt.Color('count(degree_p):Q', scale=alt.Scale(scheme='lightorange')),
).properties(width=600,height=400,title="Degree and Test Percentage of Placed Comm&mgmnt candidates")

# %% [markdown]
# <a id="75"></a>
# <font color="blueviolet" size=+2.5><b>75. Text Over Heatmap</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
last_5_netflix=netflix[netflix['release_year']>2015]

# %%
base = alt.Chart(last_5_netflix).transform_aggregate(
    num_shows='count()',
    groupby=['type', 'release_year']
).encode(
    alt.X('type:O', scale=alt.Scale(paddingInner=0),title="Type of Program"),
    alt.Y('release_year:O', scale=alt.Scale(paddingInner=0),title="Released Year"),
).properties(width=580,height=400,title="Degree and Test Percentage of Placed Comm&mgmnt candidates")

# Configure heatmap
heatmap = base.mark_rect().encode(
    color=alt.Color('num_shows:Q',
        scale=alt.Scale(scheme='darkgold'),
        legend=alt.Legend(direction='horizontal')
    )
)

# Configure text
text = base.mark_text(baseline='middle').encode(
    text='num_shows:Q',
    color=alt.condition(
        alt.datum.num_shows > 500,
        alt.value('black'),
        alt.value('white')
    )
)

# Draw the chart
heatmap + text

# %% [markdown]
# <a id="76"></a>
# <font color="blueviolet" size=+2.5><b>76. Date Heatmap</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
covid['date']=pd.to_datetime(covid['ObservationDate'])
covid_three=covid[(covid['Country/Region']=='US')|(covid['Country/Region']=='Russia')|(covid['Country/Region']=='Mainland China')]

# %%
alt.Chart(
    covid_three.sample(5000),
    title="COVID people deaths in US,China,Russia"
).mark_rect().encode(
    x='date(date):O',
    y='month(date):O',
    color=alt.Color('max(Deaths):Q', scale=alt.Scale(scheme="inferno")),
    tooltip=[
        alt.Tooltip('monthdate(date):T', title='Date'),
        alt.Tooltip('max(Deaths):Q', title='Max Temp')
    ]
).properties(width=550,height=400)

# %% [markdown]
# <a id="77"></a>
# <font color="green" size=+2.5><b>77. Simple Scatter Error Plot</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
educat=university[(university['quality_of_education']<6)][['quality_of_education','score']].groupby('quality_of_education').agg('mean').reset_index()

# %%
yerr=4
source = pd.DataFrame({"x":educat['quality_of_education'], "y":educat['score'], "yerr":yerr})
base = alt.Chart(source).transform_calculate(
    ymin="datum.y-datum.yerr",
    ymax="datum.y+datum.yerr"
)
base

# generate the points
points = base.mark_point(
    filled=True,
    size=50,
    color='black'
).encode(
    x=alt.X('x',title="Quality of Education",scale=alt.Scale(domain=(0, 6))), 
    y=alt.Y('y', title="Score",scale=alt.Scale(domain=(70, 100))),
    tooltip=[alt.Tooltip('x',title="Quality of Education"),alt.Tooltip('y',title="Score")]
).properties(width=600,height=400,title="Quality of Education vs Score with Error bar of length 4")

#generate the error bars
errorbars = base.mark_errorbar().encode(
    x="x",
    y="ymin:Q",
    y2="ymax:Q"
)

points + errorbars

# %% [markdown]
# <a id="78"></a>
# <font color="green" size=+2.5><b>78. Grouped Bar with Error</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
windows['year']=pd.to_datetime(windows['Date']).dt.year
wind_three=windows[((windows['year']==2018)|(windows['year']==2019)|(windows['year']==2020))&
                   ((windows['Category']=='Books')|(windows['Category']=='Business')|(windows['Category']=='Lifestyle'))]

# %%
bars = alt.Chart().mark_bar().encode(
    x='year:O',
    y=alt.Y('mean(Rating)', title='Mean Yield'),
    color='year:N',
    tooltip=['year','mean(Rating)']
).properties(width=200,height=400)

error_bars = alt.Chart().mark_errorbar(extent='ci').encode(
    x='year:O',
    y='Rating:Q'
)

alt.layer(bars, error_bars, data=wind_three).facet(
    column='Category:N'
)

# %% [markdown]
# <a id="79"></a>
# <font color="green" size=+2.5><b>79. Error Bar with Standard Deviation</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
error_bars = alt.Chart(windows.sample(5000)).mark_errorbar(extent='stdev').encode(
  x=alt.X('Rating:Q', scale=alt.Scale(zero=False)),
  y=alt.Y('Category:N'),
    color=alt.value('steelblue')
).properties(width=600,height=400,title="Windows Apps Ratings for each Category with Standard Deviation")

points = alt.Chart(windows.sample(5000)).mark_point(filled=True, color='blue').encode(
  x=alt.X('Rating:Q', aggregate='mean'),
  y=alt.Y('Category:N')
)

error_bars + points

# %% [markdown]
# <a id="80"></a>
# <font color="green" size=+2.5><b>80. Error Bar with Confidence Interval</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
error_bars = alt.Chart(windows.sample(5000)).mark_errorbar(extent='ci').encode(
  x=alt.X('Rating:Q', scale=alt.Scale(zero=False)),
  y=alt.Y('Category:N'),
    color=alt.value('steelblue'),

).properties(width=600,height=400,title="Windows Apps Ratings for each Category with Confidence Interval")

points = alt.Chart(windows.sample(5000)).mark_point(filled=True, color='blue').encode(
  x=alt.X('Rating:Q', aggregate='mean'),
  y=alt.Y('Category:N'),

)

error_bars + points

# %% [markdown]
# <a id="81"></a>
# <font color="green" size=+2.5><b>81. Sorted Error Bar with Confidence Interval</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
points = alt.Chart(windows.sample(5000)).mark_point(
    filled=True,
    color='blue'
).encode(
    x=alt.X('mean(Rating)', title='Rating'),
    y=alt.Y(
        'Category',
         sort=alt.EncodingSortField(
             field='Rating',
             op='mean',
             order='descending'
         )
        
    )
).properties(
    width=600,
    height=400,
    title="Windows Apps Ratings for each Category with sorted Error Bar - Confidence Interval"
)

error_bars = points.mark_rule().encode(
    x='ci0(Rating)',
    x2='ci1(Rating)',

)

points + error_bars

# %% [markdown]
# <a id="82"></a>
# <font color="orangered" size=+2.5><b>82. Candlestick</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
cipla['Date']=pd.to_datetime(cipla['Date'])
cipla['year']=pd.to_datetime(cipla['Date']).dt.year
cipla_2020_q1=cipla[(cipla['year']==2020)&(cipla['Date']<'2020-04-30')]

# %%
open_close_color = alt.condition("datum.Open <= datum.Close",
                                 alt.value("#06982d"),
                                 alt.value("#ae1325"))

base = alt.Chart(cipla_2020_q1).encode(
    alt.X('Date:T',
          axis=alt.Axis(
              format='%m/%d',
              labelAngle=-45,
              title='Date in 2009'
          )
    ),
    color=open_close_color
)

rule = base.mark_rule().encode(
    alt.Y(
        'Low:Q',
        title='Price',
        scale=alt.Scale(zero=False),
    ),
    alt.Y2('High:Q')
)



bar = base.mark_bar().encode(
    alt.Y('Open:Q'),
    alt.Y2('Close:Q')
).properties(
    width=600,
    height=400,
    title="CIPLA Candlestick for Q1 2020"
)

rule + bar

# %% [markdown]
# <a id="83"></a>
# <font color="olive" size=+2.5><b>83. Basic Violin</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
omr=chennai_house[chennai_house['Location']=='Thoraipakkam OMR']

# %%
alt.Chart(omr).transform_density(
    'Price',
    as_=['Price', 'density'],
   # extent=[5, 50],
    groupby=['Location']
).mark_area(orient='horizontal').encode(
    y='Price:Q',
    color='Location:N',
    tooltip=['Price:Q'],
    x=alt.X(
        'density:Q',
        stack='center',
        impute=None,
        title=None,
        axis=alt.Axis(labels=False, values=[0],grid=False, ticks=True),
    ),
    column=alt.Column(
        'Location:N',
        header=alt.Header(
            titleOrient='bottom',
            labelOrient='bottom',
            labelPadding=0,
        ),
    )
).properties(
    width=600,height=400,title="Distribution of House Prices in OMR-Chennai"
).configure_facet(
    spacing=0
).configure_view(
    stroke=None
)

# %% [markdown]
# <a id="84"></a>
# <font color="olive" size=+2.5><b>84. Multiple Violin</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
chennai_areas=chennai_house[(chennai_house['Location']=='Ambattur')
                           |(chennai_house['Location']=='Sholinganallur')|
                           (chennai_house['Location']=='Porur')]

# %%
alt.Chart(chennai_areas).transform_density(
    'Price',
    as_=['Price', 'density'],
    groupby=['Location']
).mark_area(orient='horizontal').encode(
    y='Price:Q',
    color='Location:N',
    x=alt.X(
        'density:Q',
        stack='center',
        impute=None,
        title=None,
        axis=alt.Axis(labels=False, values=[0],grid=False, ticks=True),
    ),
    column=alt.Column(
        'Location:N',
        header=alt.Header(
            titleOrient='bottom',
            labelOrient='bottom',
            labelPadding=0,
        ),
    ),
    tooltip=['Location','Price']
).properties(
    width=180,height=400,title="Distribution of House Prices in Chennai Areas"
).configure_facet(
    spacing=0
).configure_view(
    stroke=None
)

# %% [markdown]
# <a id="85"></a>
# <font color="limegreen" size=+2.5><b>85. Gantt Chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
stocks = pd.DataFrame([
    {"task": "AXIS", "start": axis['Close'].min(), "end": axis['Close'].max()},
    {"task": "HDFC", "start": hdfc['Close'].min(), "end": hdfc['Close'].max()},
    {"task": "ICICI", "start": icici['Close'].min(), "end": icici['Close'].max()},
    {"task": "INDUS", "start": indus['Close'].min(), "end": indus['Close'].max()},
    {"task": "KOTAK", "start": kotak['Close'].min(), "end": kotak['Close'].max()}
])
stocks['diff']=stocks['end']-stocks['start']

# %%
alt.Chart(stocks).mark_bar().encode(
    x='start',
    x2='end',
    y='task'
).properties(
    width=600,height=400,title="Min & Max Close Price of Indian Bank Stocks")

# %% [markdown]
# <a id="86"></a>
# <font color="limegreen" size=+2.5><b>86. Gantt Color & Mean Chart</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
base = alt.Chart(stocks)

bar=base.mark_bar().encode(
    x='start',
    x2='end',
    y='task',
    color='task',
    tooltip=['start','end','task']
).properties(
    width=600,height=400,title="Min & Max Close Price of Indian Bank Stocks with Color and Mean Difference")

rule = base.mark_rule(color='red').encode(
    x='mean(diff)',
    size=alt.value(5),
    tooltip=[alt.Tooltip('mean(diff)')]
)
bar+rule

# %% [markdown]
# <a id="87"></a>
# <font color="teal" size=+2.5><b>87. Ridgeline</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
weather = data.seattle_weather.url

# %%
step = 20
overlap = 1

alt.Chart(weather, height=step).transform_timeunit(
    Month='month(date)'
).transform_joinaggregate(
    mean_temp='mean(temp_max)', groupby=['Month']
).transform_bin(
    ['bin_max', 'bin_min'], 'temp_max'
).transform_aggregate(
    value='count()', groupby=['Month', 'mean_temp', 'bin_min', 'bin_max']
).transform_impute(
    impute='value', groupby=['Month', 'mean_temp'], key='bin_min', value=0
).mark_area(
    interpolate='monotone',
    fillOpacity=0.8,
    stroke='lightgray',
    strokeWidth=0.5
).encode(
    alt.X('bin_min:Q', bin='binned', title='Maximum Daily Temperature (C)'),
    alt.Y(
        'value:Q',
        scale=alt.Scale(range=[step, -step * overlap]),
        axis=None
    ),
    alt.Fill(
        'mean_temp:Q',
        legend=None,
        scale=alt.Scale(domain=[30, 5], scheme='redyellowblue')
    )
).facet(
    row=alt.Row(
        'Month:T',
        title=None,
        header=alt.Header(labelAngle=0, labelAlign='right', format='%B')
    )
).properties(
    title='Seattle Weather',
    bounds='flush'
).configure_facet(
    spacing=0
).configure_view(
    stroke=None
).configure_title(
    anchor='end'
)

# %% [markdown]
# <a id="88"></a>
# <font color="firebrick" size=+2.5><b>88. Choropleth</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
counties_us = alt.topo_feature(data.us_10m.url, 'counties')
unemploy = data.unemployment.url

# %%
alt.Chart(counties_us).mark_geoshape().encode(
    color='rate:Q',
    tooltip=['rate:Q']
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(unemploy, 'id', ['rate'])
).project(
    type='albersUsa' # To know more types - https://altair-viz.github.io/user_guide/generated/toplevel/altair.Chart.html#altair.Chart.project
).properties(
    width=600,
    height=400,
    title="Unemployment Rate in United States"
    
)

# %% [markdown]
# <a id="89"></a>
# <font color="firebrick" size=+2.5><b>89. Location</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
airports = data.airports.url
states = alt.topo_feature(data.us_10m.url, feature='states')

# %%
# US states background
background = alt.Chart(states).mark_geoshape(
    fill='lightgray',
    stroke='white'
).properties(
    width=600,
    height=400
).project('albersUsa')

# airport positions on background
points = alt.Chart(airports).transform_aggregate(
    latitude='mean(latitude)',
    longitude='mean(longitude)',
    count='count()',
    groupby=['state']
).mark_circle().encode(
    longitude='longitude:Q',
    latitude='latitude:Q',
    size=alt.Size('count:Q', title='Number of Airports'),
    color=alt.value('steelblue'),
    tooltip=['state:N','count:Q']
).properties(
    title='Number of airports in US'
)

background + points

# %% [markdown]
# <a id="90"></a>
# <font color="firebrick" size=+2.5><b>90. Repeated Choropleth</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
states = alt.topo_feature(data.us_10m.url, 'states')
source = data.population_engineers_hurricanes.url
variable_list = ['population', 'engineers', 'hurricanes']

# %%
 alt.Chart(states).mark_geoshape().encode(
    alt.Color(alt.repeat('row'), type='quantitative'),
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(source, 'id', variable_list),
).properties(
    width=600,
    height=400,
    title="Population,Engineers and Hurricanes in USA"
).project(
    type='albersUsa'
).repeat(
    row=variable_list
).resolve_scale(
    color='independent'
)

# %% [markdown]
# <a id="91"></a>
# <font color="firebrick" size=+2.5><b>91. Facet</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
states = alt.topo_feature(data.us_10m.url, 'states')
source = data.income.url

# %%
alt.Chart(source).mark_geoshape().encode(
    shape='geo:G',
    color='pct:Q',
    tooltip=['name:N','region:N','pct:Q','total:Q'],
    facet=alt.Facet('group:N', columns=2),
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(data=states, key='id'),
    as_='geo'
).properties(
    width=370,
    height=175,
    title="US Income by State"
).project(
    type='albersUsa'
)

# %% [markdown]
# <a id="92"></a>
# <font color="firebrick" size=+2.5><b>92. World Map</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
# Data generators for the background
sphere = alt.sphere()
graticule = alt.graticule()

# Source of land data
source = alt.topo_feature(data.world_110m.url, 'countries')

# %%
# Layering and configuring the components
alt.layer(
    alt.Chart(sphere).mark_geoshape(fill='lightblue'),
    alt.Chart(graticule).mark_geoshape(stroke='white', strokeWidth=0.5),
    alt.Chart(source).mark_geoshape(fill='ForestGreen', stroke='black')
).project(
    'naturalEarth1'
).properties(width=600, height=400).configure_view(stroke=None)

# %% [markdown]
# <a id="93"></a>
# <font color="firebrick" size=+2.5><b>93. World Map Projections</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
source = alt.topo_feature(data.world_110m.url, 'countries')

# %%
base = alt.Chart(source).mark_geoshape(
    fill='darkblue', #666666
    stroke='white'
).properties(
    width=300,
    height=180
)

projections = ['equirectangular', 'mercator', 'orthographic', 'gnomonic']
charts = [base.project(proj).properties(title=proj)
          for proj in projections]

alt.concat(*charts, columns=2)

# %% [markdown]
# <a id="94"></a>
# <font color="deeppink" size=+2.5><b>94. Interactive Average</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
infy_3=infy[(infy['Date']>'2016-12-31')&(infy['Date']<'2020-01-01')]

# %%
brush = alt.selection(type='interval', encodings=['x'])

bars = alt.Chart().mark_bar(color="green").encode(
    x=alt.X('month(Date):O',title="Month"),
    y=alt.Y('mean(Last):Q',title="Last Price"),
    opacity=alt.condition(brush, alt.OpacityValue(1), alt.OpacityValue(0.7)),
    tooltip=['month(Date)','mean(Last)']
).add_selection(
    brush
).properties(height=400,width=600,title="Monthly Last Price of Infy (2017-2019) - Drag over bars and find average")

line = alt.Chart().mark_rule(color='firebrick').encode(
    y='mean(Last):Q',
    size=alt.SizeValue(3),
    tooltip=['mean(Last)']
).transform_filter(
    brush
)

alt.layer(bars, line, data=infy_3)

# %% [markdown]
# <a id="95"></a>
# <font color="deeppink" size=+2.5><b>95. Interactive Chart with Cross-Highlight</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
titanic=titanic.dropna()

# %%
pts = alt.selection(type="single", encodings=['x'])

rect = alt.Chart(titanic).mark_rect().encode(
    alt.X('Age:Q', bin=True),
    alt.Y('Fare:Q', bin=True),
    alt.Color('count()',
        scale=alt.Scale(scheme='purplered'),
        legend=alt.Legend(title='Total Records')
    )
)

circ = rect.mark_point().encode(
    alt.ColorValue('grey'),
    alt.Size('count()',
        legend=alt.Legend(title='Records in Selection')
    )
).transform_filter(
    pts
)

bar = alt.Chart(titanic).mark_bar().encode(
    x='Embarked:N',
    y='count()',
    color=alt.condition(pts, alt.ColorValue("purple"), alt.ColorValue("grey")),
    tooltip=['Embarked','count()']
).properties(
    width=600,
    height=400,title="Interactive Cross filter of People Age and Fare who embarked from different stations"
).add_selection(pts)

alt.vconcat(
    rect + circ,
    bar
).resolve_legend(
    color="independent",
    size="independent"
)

# %% [markdown]
# <a id="96"></a>
# <font color="deeppink" size=+2.5><b>96. Interactive Chart with Crossfilter</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
ind_covid=covid[covid['Country/Region']=='India']

# %%
brush = alt.selection(type='interval', encodings=['x'])

# Define the base chart, with the common parts of the
# background and highlights
base = alt.Chart().mark_bar().encode(
    x=alt.X(alt.repeat('column'), type='quantitative', bin=alt.Bin(maxbins=20)),
    y='count()',
).properties(
    width=180,
    height=350
)

# gray background with selection
background = base.encode(
    color=alt.value('#ddd')
).add_selection(brush)

# blue highlights on the transformed data
highlight = base.transform_filter(brush)

# layer the two charts & repeat
alt.layer(
    background,
    highlight,
    data=ind_covid
).repeat(column=["Confirmed", "Deaths", "Recovered"])

# %% [markdown]
# <a id="97"></a>
# <font color="deeppink" size=+2.5><b>97. Interactive Legend</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
windows=windows.dropna()

# %%
selection = alt.selection_multi(fields=['Category'], bind='legend')

alt.Chart(windows.sample(5000)).mark_area().encode(
    alt.X('yearmonth(Date):T', axis=alt.Axis(domain=False, format='%Y', tickSize=0)),
    alt.Y('mean(Rating):Q', stack='center', axis=None),
    alt.Color('Category:N', scale=alt.Scale(scheme='category20b')),
    tooltip=['yearmonth(Date)','mean(Rating)','Category'],
    opacity=alt.condition(selection, alt.value(1), alt.value(0.2))
).add_selection(
    selection
).properties(width=600,height=400,title="Average Ratings of Windows Apps Category")

# %% [markdown]
# <a id="98"></a>
# <font color="deeppink" size=+2.5><b>98. Interactive Rectangular Brush</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
chennai_house['Bedrooms']=chennai_house['No. of Bedrooms']

# %%
brush = alt.selection(type='interval')

alt.Chart(chennai_house.sample(5000)).mark_point().encode(
    x='Area:Q',
    y='Price:Q',
    color=alt.condition(brush, 'Bedrooms:O', alt.value('grey')),
).add_selection(brush).properties(width=600,height=400,title="Chennai Houses - Area vs Price against Number of Bedrooms")

# %% [markdown]
# <a id="99"></a>
# <font color="deeppink" size=+2.5><b>99. Interactive Scatter Plot and Linked Layered Histogram</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
def find_age_stay(start,end):
    result=np.random.randint(start,end)
    return result

health['Stay']=np.where(health['Stay']=="0-10","1-10",health['Stay'])
health['Stay']=np.where(health['Stay']=="More than 100 Days","101-110",health['Stay'])

health[['start_age','end_age']] = health['Age'].str.split('-',expand=True)
health[['start_stay','end_stay']] = health['Stay'].str.split('-',expand=True)
health['end_age']=health['end_age'].astype(int)+1
health['end_stay']=health['end_stay'].astype(int)+1

health['Age_num']=health[['start_age','end_age']].apply(lambda x:find_age_stay(*x), axis=1)
health['Stay_days']=health[['start_stay','end_stay']].apply(lambda x:find_age_stay(*x), axis=1)
health['Age_num']=health['Age_num'].astype(int)
health['Stay_days']=health['Stay_days'].astype(int)
age_stay=health[['Age_num','Stay_days']]

# %%
selector = alt.selection_single(empty='all', fields=['Severity of Illness'])

color_scale = alt.Scale(domain=['Minor', 'Moderate','Extreme'],
                        range=['green', 'orange','red'])

base = alt.Chart(health.sample(5000)).properties(
    width=280,
    height=200
).add_selection(selector)

points = base.mark_point(filled=True, size=200).encode(
    x=alt.X('mean(Age_num):Q',title="Age - Mean",
            scale=alt.Scale(domain=[20,100])),
    y=alt.Y('mean(Stay_days):Q',title="Stay Days - Mean",
            scale=alt.Scale(domain=[0,60])),
    color=alt.condition(selector,
                        'Severity of Illness:N',
                        alt.value('lightgray'),
                        scale=color_scale),
)

hists = base.mark_bar(opacity=0.5, thickness=100).encode(
    x=alt.X('Age_num',
            bin=alt.Bin(step=5), # step keeps bin size the same
            scale=alt.Scale(domain=[0,100])),
    y=alt.Y('count()',
            stack=None,
            scale=alt.Scale(domain=[0,350])),

    color=alt.Color('Severity of Illness:N',
                    scale=color_scale)
).transform_filter(
    selector
)


points | hists

# %% [markdown]
# <a id="100"></a>
# <font color="deeppink" size=+2.5><b>100. Multi-Line Highlight</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
covid['date']=pd.to_datetime(covid['ObservationDate'])
covid_four=covid[((covid['Country/Region']=='US')|(covid['Country/Region']=='Russia')|
      (covid['Country/Region']=='Japan')|(covid['Country/Region']=='Mexico'))]
covid_four_country=covid_four[['Country/Region','date','Deaths']].groupby(['Country/Region','date']).agg('sum').reset_index()

# %%
highlight = alt.selection(type='single', on='mouseover',
                          fields=['Country/Region'], nearest=True)

base = alt.Chart(covid_four_country).encode(
    x='date:T',
    y='Deaths:Q',
    color='Country/Region:N'
)

points = base.mark_circle().encode(
    opacity=alt.value(0)
).add_selection(
    highlight
).properties(
    width=580,height=400,title="COVID Deaths in China,Japan,Russia,US"
)

lines = base.mark_line().encode(
    size=alt.condition(~highlight, alt.value(1), alt.value(3))
)

points + lines

# %% [markdown]
# <a id="101"></a>
# <font color="deeppink" size=+2.5><b>101. Multi-panel Scatter Plot with Linked Brushing</b></font>
#
# <a href="#top" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOC</a>

# %%
placed=campus[campus['salary'].notnull()]

# %%
brush = alt.selection(type='interval', resolve='global')

base = alt.Chart(placed).mark_point().encode(
    y='salary',
    color=alt.condition(brush, 'degree_t', alt.ColorValue('gray')),
).add_selection(
    brush
).properties(
    width=270,
    height=400
)

base.encode(x='degree_p') | base.encode(x='etest_p')

# %% [markdown]
# <font color="magenta" size="+2">Work In Progress 🚧</font>

# %% [markdown]
# <font color="chocolate" size=+2.5><b>End Note</b></font>
#
# I hope you enjoyed my kernel.Also you might have forked it for future use.Please dont forget to appreciate me with an <font size=+1 color="red"><b>Upvote</b></font>.
#
# Thanks for your time.
#
# Happy Kaggling!!!

# %% [markdown]
# <font color="chocolate" size=+2.5><b>My Other Kernels</b></font>
#
# Click on the button to view kernel...
#
# <a href="https://www.kaggle.com/raenish/healthcare-investigation-altair-charts/" class="btn btn-success" style="color:white;">Healthcare Investigation</a><br><br>
# <a href="https://www.kaggle.com/raenish/kaggle-users-competitions-stats-eda" class="btn btn-success" style="color:white;">Kaggle Users & Competition EDA</a><br><br>
# <a href="https://www.kaggle.com/raenish/kaggle-notebooks-stats-eda" class="btn btn-success" style="color:white;">Kaggle Notebook EDA</a><br><br>
# <a href="https://www.kaggle.com/raenish/covid19-tweets-interactive-eda" class="btn btn-success" style="color:white;">#COVID19 EDA</a><br><br>
# <a href="https://www.kaggle.com/raenish/self-evaluation-kaggle-profiler" class="btn btn-success" style="color:white;">Kaggle Profiler</a><br><br>
# <a href="https://www.kaggle.com/raenish/cheatsheet-100-plotly-part-1-basic/" class="btn btn-success" style="color:white;">100+ Plotly Part 1</a><br><br>
# <a href="https://www.kaggle.com/raenish/cheatsheet-100-plotly-part-2-advanced" class="btn btn-success" style="color:white;">100+ Plotly Part 2</a><br><br>
# <a href="https://www.kaggle.com/raenish/become-grandmaster/" class="btn btn-success" style="color:white;">Become GrandMaster</a><br><br>
# <a href="https://www.kaggle.com/raenish/don-t-shoot" class="btn btn-success" style="color:white;">Dont Shoot</a><br><br>
# <a href="https://www.kaggle.com/raenish/cheatsheet-date-helpers/" class="btn btn-success" style="color:white;">Cheatsheet Date Helpers</a><br><br>
# <a href="https://www.kaggle.com/raenish/cheatsheet-text-helper-functions/" class="btn btn-success" style="color:white;">Cheatsheet Text Helpers</a><br><br>
# <a href="https://www.kaggle.com/raenish/tweet-sentiment-insight-eda/" class="btn btn-success" style="color:white;">Tweet Sentiment Extraction</a><br><br>
#
# ### If these kernels impress you,give them an <font size="+2" color="red"><b>Upvote</b></font>.<br>

# %% [markdown]
# <a href="#top" class="btn btn-primary" role="button" aria-pressed="true" style="color:white" data-toggle="popover" title="go to Colors">Go to TOP</a>
